# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
plt.figure(1,figsize=(15, 6))
n = 0
for x in ["Age",	"Annual Income (k$)" ,	"Spending Score (1-100)"]:
    n += 1
    plt.subplot( 1,3,n)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.distplot(df[x], bins=20, kde=True)  # Use histplot with kde=True for smooth density curve
    plt.title('Distplot of {}'.format(x))
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15896\245046702.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x], bins=20, kde=True)  # Use histplot with kde=True for smooth density curve
# C:\Users\User\AppData\Local\Temp\ipykernel_15896\245046702.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(y="Gender",data=df)
plt.show()

# %%
plt.figure(1,figsize=(15,7))
n=0
for x1 in ["Age","Annual Income (k$)","Spending Score (1-100)"]: 
    # plt.subplot (1,3,n)
    n=n + 1
    plt.subplot (1,3,n)
    sns.set(style="whitegrid")
    plt.subplots_adjust(hspace=0.5,wspace=0.5)
    sns.violinplot(x=x1,y="Gender",data=df)
    plt.ylabel("Gender" if n==1 else " ")
plt.show()

# %%
age_18_25=df.Age[(df.Age >= 18) & (df.Age<=25)]
age_26_35=df.Age[(df.Age >= 26) & (df.Age)]
age_36_45=df.Age[(df.Age >= 36) & (df.Age<=45)]
age_46_55=df.Age[(df.Age >= 46) & (df.Age<=55)]
age_55 = df.Age[(df.Age >= 55)]

# %%
agex=["age_18_25","age_26_35","age_36_45","age_46_55","age_55"]
agey=[len(age_18_25.values),len(age_26_35.values),len(age_36_45.values),len(age_46_55.values),len(age_55.values)]
plt.figure(figsize=(7,10))
sns.barplot(x=agex,y=agey)
plt.title("number of customer and ages")
plt.xlabel("age")
plt.ylabel("values")
plt.show()

# %%
sns.relplot(x="Annual Income (k$)",y="Spending Score (1-100)",data=df)
plt.show()

# %%
ss_1_20=df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=1) & (df["Spending Score (1-100)"]<=20)]
ss_21_40=df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=21) & (df["Spending Score (1-100)"]<=40)]
ss_41_60=df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=41) & (df["Spending Score (1-100)"]<=60)]
ss_61_80=df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=61) & (df["Spending Score (1-100)"]<=80)]
ss_81_100=df["Spending Score (1-100)"][(df["Spending Score (1-100)"])>=81 & (df["Spending Score (1-100)"]<=100)]
ssx=["ss_1_20","ss_21_40","ss_41_60","ss_61_80","ss_81_100"]
ssy=[len(ss_1_20.values),len(ss_21_40.values),len(ss_41_60.values),len(ss_61_80.values),len(ss_81_100.values)]

# %%
plt.figure(figsize=(6,6))
sns.barplot(x=ssx,y=ssy)
plt.title("number of spending score")
plt.show()

# %%
ai_15_35=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=15) & (df["Annual Income (k$)"]<=35)]
ai_36_55=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=36) & (df["Annual Income (k$)"]<=55)]
ai_56_75=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=56) & (df["Annual Income (k$)"]<=75)]
ai_76_95=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=76) & (df["Annual Income (k$)"]<=95)]
ai_gr100=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=100)]

# %%
aix=["ai_15_35","ai_36_55","ai_56_75","ai_76_95","ai_gr100"]
aiy=[len(ai_15_35.values),len(ai_15_35.values),len(ai_56_75.values),len(ai_76_95.values),len(ai_gr100.values)]
sns.barplot(x=aix,y=aiy,palette="Spectral")
plt.title("annual income")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15896\4029726606.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=aix,y=aiy,palette="Spectral")
